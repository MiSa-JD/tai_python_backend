# %%
# %pip install feedparser
# Out:
# Collecting feedparser
#   Downloading feedparser-6.0.12-py3-none-any.whl.metadata (2.7 kB)
# Collecting sgmllib3k (from feedparser)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Downloading feedparser-6.0.12-py3-none-any.whl (81 kB)
# Building wheels for collected packages: sgmllib3k
#   DEPRECATION: Building 'sgmllib3k' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'sgmllib3k'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6047 sha256=cdae16d7176d2fd330fec1edf537fff00d1fc6c3c47b4b4ef3de4f3ef2db0e5c
#   Stored in directory: /Users/jeong-ug/Library/Caches/pip/wheels/3d/4d/ef/37cdccc18d6fd7e0dd7817dcdf9146d4d6789c32a227a28134
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [feedparser]
# Successfully installed feedparser-6.0.12 sgmllib3k-1.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import feedparser

feed = feedparser.parse("https://trends.google.co.kr/trending/rss?geo=KR")

for i in range(len(feed.entries)):
  print(i+1, "등: ", feed.entries[i]['title'])
# print( feed.entries[7])
# Out:
# 1 등:  김문수
# 2 등:  케이뱅크
# 3 등:  연세대학교
# 4 등:  지스타
# 5 등:  블랙프라이데이
# 6 등:  오스틴 리브스
# 7 등:  빙부상
# 8 등:  kings vs lakers
# 9 등:  황교안
# 10 등:  베레모

# %%
for texts in feed.entries[0]:
  print(texts, ":", feed.entries[0][texts])
# Out:
# title : 김문수
# title_detail : {'type': 'text/plain', 'language': None, 'base': 'https://trends.google.co.kr/trending/rss?geo=KR', 'value': '김문수'}
# ht_approx_traffic : 200+
# summary :
# summary_detail : {'type': 'text/html', 'language': None, 'base': 'https://trends.google.co.kr/trending/rss?geo=KR', 'value': ''}
# links : [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://trends.google.com/trending/rss?geo=KR'}]
# link : https://trends.google.com/trending/rss?geo=KR
# published : Sun, 26 Oct 2025 21:30:00 -0700
# published_parsed : time.struct_time(tm_year=2025, tm_mon=10, tm_mday=27, tm_hour=4, tm_min=30, tm_sec=0, tm_wday=0, tm_yday=300, tm_isdst=0)
# ht_picture : https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTt6vEVXKzC7xyvqUeHJcqsnz1FYA9yUgLyF-GJMWgpcetorB3J35x2OZ07zfE
# ht_picture_source : 경향신문
# ht_news_item_title : 구미시, '박정희 대통령 서거 46주기 추모제 및 추도식' 개최
# ht_news_item_snippet :
# ht_news_item_url : https://www.sisamagazine.co.kr/news/articleView.html?idxno=519627
# ht_news_item_picture : https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcShUB2HZQPMSbeByxw6jImR24eCm6syKGFXBOLGwG1NwX6yaJ9mIz4j7B-bQFw
# ht_news_item_source : 시사매거진
# ht_news_item :

# %%
feed.entries
# Out:
# [{'title': '김문수',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://trends.google.co.kr/trending/rss?geo=KR',
#    'value': '김문수'},
#   'ht_approx_traffic': '200+',
#   'summary': '',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://trends.google.co.kr/trending/rss?geo=KR',
#    'value': ''},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://trends.google.com/trending/rss?geo=KR'}],
#   'link': 'https://trends.google.com/trending/rss?geo=KR',
#   'published': 'Sun, 26 Oct 2025 21:30:00 -0700',
#   'published_parsed': time.struct_time(tm_year=2025, tm_mon=10, tm_mday=27, tm_hour=4, tm_min=30, tm_sec=0, tm_wday=0, tm_yday=300, tm_isdst=0),
#   'ht_picture': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTt6vEVXKzC7xyvqUeHJcqsnz1FYA9yUgLyF-GJMWgpcetorB3J35x2OZ07zfE',
#   'ht_picture_source': '경향신문',
#   'ht_news_item_title': "구미시, '박정희 대통령 서거 46주기 추모제 및 추도식' 개최",
#   'ht_news_item_snippet': '',
#   'ht_news_item_url': 'https://www.sisamagazine.co.kr/news/articleView.html?idxno=519627',
#   'ht_news_item_picture': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcShUB2HZQPMSbeByxw6jImR24eCm6syKGFXBOLGwG1NwX6yaJ9mIz4j7B-bQFw',
#   'ht_news_item_source': '시사매거진',
#   'ht_news_item': ''},
#  {'title': '케이뱅크',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://trends.google.co.kr/trending/rss?geo=KR',
#    'value': '케이뱅크'},
#   'ht_approx_traffic': '100+',
#   'summary': '',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://trends.google.co.kr/trending/rss?geo=KR',
#    'value': ''},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://trends.google.com/trending/rss?geo=KR'}],
#   'link': 'https://trends.google.com/trending/rss?geo=KR',
#   'published': 'Sun, 26 Oct 2025 21:30:00 -0700',
#   'published_parsed': time.struct_time(tm_year=2025, tm_mon=10, tm_mday=27, tm_hour=4, tm_min=30, tm_sec=0, tm_wday=0, tm_yday=300, tm_isdst=0),
#   'ht_picture': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcT6V7UhIljwbPSe1wWItaUQCLQhb33w_iIOe0IlEbD80bAiCYQsDludaPWjCSY',
#   'ht_picture_source': '네이트',
#   'ht_news_item_title': "케이뱅크, 고객 '1500만명' 돌파…자영업자 유입 효과 톡톡히",
#   'ht_news_item_snippet': '',
#   'ht_news_item_url': 'https://news.zum.com/articles/101487349/%EC%BC%80%EC%9D%B4%EB%B1%85%ED%81%AC-%EA%B3%A0%EA%B0%9D-1500%EB%A7%8C%EB%AA%85-%EB%8F%8C%ED%8C%8C-%EC%9E%90%EC%98%81%EC%97%85%EC%9E%90-%EC%9C%A0%EC%9E%85-%ED%9A%A8%EA%B3%BC-%ED%86%A1%ED%86%A1%ED%9E%88',
#   'ht_news_item_picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcRcG-aT5DknsjXMSGbcibbEHWA8eRlCCrwla0_uOk7ML5mKe7E1pZ5CV3wTk_4',
#   'ht_news_item_source': 'ZUM 뉴스',
#   'ht_news_item': ''},
#  {'title': '연세대학교',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://trends.google.co.kr/trending/rss?geo=KR',
#    'value': '연세대학교'},
#   'ht_approx_traffic': '100+',
#   'summary': '',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://trends.google.co.kr/trending/rss?geo=KR',
#    'value': ''},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://trends.google.com/trending/rss?geo=KR'}],
#   'link': 'https://trends.google.com/trending/rss?geo=KR',
#   'published': 'Sun, 26 Oct 2025 21:20:00 -0700',
#   'published_parsed': time.struct_time(tm_year=2025, tm_mon=10, tm_mday=27, tm_hour=4, tm_min=20, tm_sec=0, tm_wday=0, tm_yday=300, tm_isdst=0),
#   'ht_picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcSXOb3bji1QzTqYWBD9Owdl-WoH2fVdr1m41oJvdsbDbfZhu7_l6VXdRNfyym8',
#   'ht_picture_source': '한국강사신문',
#   'ht_news_item_title': '한국방사선진흥협회-IAEA, 방사선분야 국제협력 강화 PA 체결',
#   'ht_news_item_snippet': '',
#   'ht_news_item_url': 'http://www.knpnews.com/news/articleView.html?idxno=32916',
#   'ht_news_item_picture': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcQ93e-4_QeLxiB85cEC-0e5SePhPfXQdOgMDIawos8PXsagOXlfL9LCDXCoubk',
#   'ht_news_item_source': '한국원자력신문',
#   'ht_news_item': ''},
#  {'title': '지스타',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://trends.google.co.kr/trending/rss?geo=KR',
#    'value': '지스타'},
#   'ht_approx_traffic': '200+',
#   'summary': '',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://trends.google.co.kr/trending/rss?geo=KR',
#    'value': ''},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://trends.google.com/trending/rss?geo=KR'}],
#   'link': 'https://trends.google.com/trending/rss?geo=KR',
#   'published': 'Sun, 26 Oct 2025 21:10:00 -0700',
#   'published_parsed': time.struct_time(tm_year=2025, tm_mon=10, tm_mday=27, tm_hour=4, tm_min=10, tm_sec=0, tm_wday=0, tm_yday=300, tm_isdst=0),
#   'ht_picture': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcSU91Ll6NKuepN5V7IeJEW5C7ByahfPFa2Hm4CorSsM6oIBA0jhUWvlUoVvLfg',
#   'ht_picture_source': '게임뷰',
#   'ht_news_item_title': "크래프톤 '팰월드 모바일', 엔씨 '아이온2'... 기대 신작 지스타 달군다",
#   'ht_news_item_snippet': '',
#   'ht_news_item_url': 'https://www.etnews.com/20251024000186',
#   'ht_news_item_picture': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcSzv208O53DgXMpHZdAqUkDo0pcuWvJWnnPo2tJQfcbdMUhnfU2mb-U9FtXh7I',
#   'ht_news_item_source': '전자신문',
#   'ht_news_item': ''},
#  {'title': '블랙프라이데이',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://trends.google.co.kr/trending/rss?geo=KR',
#    'value': '블랙프라이데이'},
#   'ht_approx_traffic': '100+',
#   'summary': '',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://trends.google.co.kr/trending/rss?geo=KR',
#    'value': ''},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://trends.google.com/trending/rss?geo=KR'}],
#   'link': 'https://trends.google.com/trending/rss?geo=KR',
#   'published': 'Sun, 26 Oct 2025 21:00:00 -0700',
#   'published_parsed': time.struct_time(tm_year=2025, tm_mon=10, tm_mday=27, tm_hour=4, tm_min=0, tm_sec=0, tm_wday=0, tm_yday=300, tm_isdst=0),
#   'ht_picture': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRvSANNrGirZERAmDfQuXLrfxiDbRGo6QuFzMEFmcNo0tqU8ZUYwxSfMaZqZcQ',
#   'ht_picture_source': '연합뉴스',
#   'ht_news_item_title': '[오늘의 장바구니] 홈플러스·팝마트 코리아·카카오스타일·신라호텔 외',
#   'ht_news_item_snippet': '',
#   'ht_news_item_url': 'https://news.nate.com/view/20251027n10523',
#   'ht_news_item_picture': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcSRcjDCS4pLsVzbI__tM8w0ov2eU1ehVDhqYWfaQtR_FsNMfQj4WbzjaHRoVOI',
#   'ht_news_item_source': '네이트',
#   'ht_news_item': ''},
#  {'title': '오스틴 리브스',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://trends.google.co.kr/trending/rss?geo=KR',
#    'value': '오스틴 리브스'},
#   'ht_approx_traffic': '200+',
#   'summary': '',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://trends.google.co.kr/trending/rss?geo=KR',
#    'value': ''},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://trends.google.com/trending/rss?geo=KR'}],
#   'link': 'https://trends.google.com/trending/rss?geo=KR',
#   'published': 'Sun, 26 Oct 2025 20:50:00 -0700',
#   'published_parsed': time.struct_time(tm_year=2025, tm_mon=10, tm_mday=27, tm_hour=3, tm_min=50, tm_sec=0, tm_wday=0, tm_yday=300, tm_isdst=0),
#   'ht_picture': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcTYsm6ra5sMJNyiqTHYaZXBs6qF3cBI-CvKPiQPJfuJm0j6rIQ5acdqHKUBKos',
#   'ht_picture_source': '매일경제',
#   'ht_news_item_title': "르브론 없고 돈치치 빠져도 레이커스엔 '오스틴 파워'가 있어 든든···개인 최다 51점 '맹폭', 레이커스는 새크라멘토 잡고 2연승",
#   'ht_news_item_snippet': '',
#   'ht_news_item_url': 'https://sports.news.nate.com/view/20251027n19869',
#   'ht_news_item_picture': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcQfwX2fObbW07VZgRH2EfeiuNZVwBLgfW1S_YO2p-I2rjBINWMdNUu6alSoeGU',
#   'ht_news_item_source': '네이트 스포츠',
#   'ht_news_item': ''},
#  {'title': '빙부상',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://trends.google.co.kr/trending/rss?geo=KR',
#    'value': '빙부상'},
#   'ht_approx_traffic': '100+',
#   'summary': '',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://trends.google.co.kr/trending/rss?geo=KR',
#    'value': ''},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://trends.google.com/trending/rss?geo=KR'}],
#   'link': 'https://trends.google.com/trending/rss?geo=KR',
#   'published': 'Sun, 26 Oct 2025 20:40:00 -0700',
#   'published_parsed': time.struct_time(tm_year=2025, tm_mon=10, tm_mday=27, tm_hour=3, tm_min=40, tm_sec=0, tm_wday=0, tm_yday=300, tm_isdst=0),
#   'ht_picture': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQPMu1dwobQnXbqADe01tG3o44tuj6H5nvpjgnsleMQ93mt-I5-_BSoClKGX3g',
#   'ht_picture_source': '연합뉴스',
#   'ht_news_item_title': '강창동 교촌에프앤비 커뮤니케이션부문 사장 빙부상',
#   'ht_news_item_snippet': '',
#   'ht_news_item_url': 'https://www.hankyung.com/article/202510274597g',
#   'ht_news_item_picture': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ-ejf2ySa7x3O2wXX9QRboKh_rR-QPSi5oi5z4nCORcRtjzOoZVRHQobQqDxg',
#   'ht_news_item_source': '한국경제',
#   'ht_news_item': ''},
#  {'title': 'kings vs lakers',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://trends.google.co.kr/trending/rss?geo=KR',
#    'value': 'kings vs lakers'},
#   'ht_approx_traffic': '200+',
#   'summary': '',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://trends.google.co.kr/trending/rss?geo=KR',
#    'value': ''},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://trends.google.com/trending/rss?geo=KR'}],
#   'link': 'https://trends.google.com/trending/rss?geo=KR',
#   'published': 'Sun, 26 Oct 2025 20:10:00 -0700',
#   'published_parsed': time.struct_time(tm_year=2025, tm_mon=10, tm_mday=27, tm_hour=3, tm_min=10, tm_sec=0, tm_wday=0, tm_yday=300, tm_isdst=0),
#   'ht_picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcTfHOXrgWJtIZ_LGw7Fch-94VYhriTb5GcsLt8zGOcmNG5_xJYMOe4ufsQKO_A',
#   'ht_picture_source': 'beritasriwijaya.co.id',
#   'ht_news_item_title': 'Injured Lakers Starter Ruled Out for Rest of Kings Showdown',
#   'ht_news_item_snippet': '',
#   'ht_news_item_url': 'https://www.si.com/nba/lakers/onsi/news/injured-lakers-starter-ruled-out-for-rest-of-kings-showdown',
#   'ht_news_item_picture': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcRCeI2dVMhcLwXhL7QzYS2uJVzNaRMSzNY9NN37Zgl9aYt54bgSFhrevQ6ZHIc',
#   'ht_news_item_source': 'Sports Illustrated',
#   'ht_news_item': ''},
#  {'title': '황교안',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://trends.google.co.kr/trending/rss?geo=KR',
#    'value': '황교안'},
#   'ht_approx_traffic': '200+',
#   'summary': '',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://trends.google.co.kr/trending/rss?geo=KR',
#    'value': ''},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://trends.google.com/trending/rss?geo=KR'}],
#   'link': 'https://trends.google.com/trending/rss?geo=KR',
#   'published': 'Sun, 26 Oct 2025 19:50:00 -0700',
#   'published_parsed': time.struct_time(tm_year=2025, tm_mon=10, tm_mday=27, tm_hour=2, tm_min=50, tm_sec=0, tm_wday=0, tm_yday=300, tm_isdst=0),
#   'ht_picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcSHwYuGnZM2pohhLKWQgzlhltJlJ_PI0yjvXjs3rr1ogiXE4kT-ZEXjcMgQLEA',
#   'ht_picture_source': '경향신문',
#   'ht_news_item_title': '황교안 단체 \'부방대\' 경찰 압수수색 … 황 "정치적 표적수사" 반발',
#   'ht_news_item_snippet': '',
#   'ht_news_item_url': 'https://www.newdaily.co.kr/site/data/html/2025/10/27/2025102700181.html',
#   'ht_news_item_picture': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcQv9rELglzf5P8S5Us2Ka5fgZROg5gfy7ccr2V_tciDMT2khBVCwmINOclm1qs',
#   'ht_news_item_source': '뉴데일리',
#   'ht_news_item': ''},
#  {'title': '베레모',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://trends.google.co.kr/trending/rss?geo=KR',
#    'value': '베레모'},
#   'ht_approx_traffic': '200+',
#   'summary': '',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://trends.google.co.kr/trending/rss?geo=KR',
#    'value': ''},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://trends.google.com/trending/rss?geo=KR'}],
#   'link': 'https://trends.google.com/trending/rss?geo=KR',
#   'published': 'Sun, 26 Oct 2025 19:10:00 -0700',
#   'published_parsed': time.struct_time(tm_year=2025, tm_mon=10, tm_mday=27, tm_hour=2, tm_min=10, tm_sec=0, tm_wday=0, tm_yday=300, tm_isdst=0),
#   'ht_picture': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcTA0kd9Q5EU76mKYeaxY6914itbUZaCINkXiu31UAXcmrSn0FyltQQsb6HoOhw',
#   'ht_picture_source': '동아일보',
#   'ht_news_item_title': '"덥고 불편하기까지"…육군, 베레모 단계적 폐지 추진',
#   'ht_news_item_snippet': '',
#   'ht_news_item_url': 'https://www.hankyung.com/article/2025102623357',
#   'ht_news_item_picture': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcQuPQflHCIU5Sjxt8w3xHGmSwmZ9xc2O2NSwqxVcScImWSIuF-pI-eldgOrOZo',
#   'ht_news_item_source': '한국경제',
#   'ht_news_item': ''}]
