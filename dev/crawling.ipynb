# %%
# %pip install requests
# Out:
# Requirement already satisfied: requests in /Users/jeong-ug/.pyenv/versions/anaconda3-2025.06-0/lib/python3.13/site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jeong-ug/.pyenv/versions/anaconda3-2025.06-0/lib/python3.13/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jeong-ug/.pyenv/versions/anaconda3-2025.06-0/lib/python3.13/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jeong-ug/.pyenv/versions/anaconda3-2025.06-0/lib/python3.13/site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jeong-ug/.pyenv/versions/anaconda3-2025.06-0/lib/python3.13/site-packages (from requests) (2025.10.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

url = 'https://www.ddaily.co.kr/page/view/2025102717081235863'

response = requests.get(url)

# %%
from bs4 import BeautifulSoup as bs

soup = bs(response.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Transition-al//EN""http://www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd">
# <html lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=1900, initial-scale=0.2, maximum-scale=3.0, minimum-scale=0.1" name="viewport"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <link href="/assets/images/common/favicon.ico" rel="shortcut icon"/>
#   <link href="/assets/images/common/favicon.ico" rel="icon"/>
#   <meta content="11fe798d13290556509dab7de5d56b5cfffba27b" name="naver-site-verification">
#    <title>
#     인기 인플루언서 총출동!…넷마블, `지스타2025` 현장 프로그램 공개 - 디지털데일리
#    </title>
#    <link href="https://www.ddaily.co.kr/upload/2023/05/03/5c4e980c462bf0af09ed4969708f3836.ico" rel="shortcut icon"/>
#    <link href="https://www.ddaily.co.kr/page/view/2025102717081235863" rel="canonical"/>
#    <meta content="인기 인플루언서 총출동!&amp;hellip;넷마블, '지스타2025' 현장 프로그램 공개 - 디지털데일리" id="meta_title" name="title">
#     <meta content="넷마블 ‘지스타 2025' 출품작. [ⓒ넷마블][디지털데일리 이학범기자] 넷마블은 오는 11월13일부터 16일까지 부산 벡스코에서 열리는 '지스타2025'에서 진행되는 출품작 5종..." name="description">
#      <meta content="이학범 기자" name="author">
#       <meta content="undefined" name="news_keywords"/>
#       <meta content="2025-10-27 [17:19:10]" name="pubDate"/>
#       <meta content="undefined" name="keywords"/>
#       <meta content="article" name="og:type" property="og:type"/>
#       <meta content="https://www.ddaily.co.kr//page/view/2025102717081235863" name="og:url" property="og:url"/>
#       <meta content="인기 인플루언서 총출동!&amp;hellip;넷마블, '지스타2025' 현장 프로그램 공개" name="og:title" property="og:title"/>
#       <meta content="넷마블 ‘지스타 2025' 출품작. [ⓒ넷마블][디지털데일리 이학범기자] 넷마블은 오는 11월13일부터 16일까지 부산 벡스코에서 열리는 '지스타2025'에서 진행되는 출품작 5종..." name="og:description" property="og:description"/>
#       <meta content="http://www.ddaily.co.kr/page/view/2025102717081235863" name="og:site" property="og:site"/>
#       <meta content="디지털데일리" name="og:site_name" property="og:site_name"/>
#       <meta content="/photos/2025/10/27/2025102717070964360_l.jpg" name="og:image" property="og:image">
#        <meta content="summary_large_image" name="twitter:card"/>
#        <meta content="인기 인플루언서 총출동!&amp;hellip;넷마블, '지스타2025' 현장 프로그램 공개" name="twitter:title"/>
#        <meta content="넷마블 ‘지스타 2025' 출품작. [ⓒ넷마블][디지털데일리 이학범기자] 넷마블은 오는 11월13일부터 16일까지 부산 벡스코에서 열리는 '지스타2025'에서 진행되는 출품작 5종..." name="twitter:description"/>
#        <meta content="/photos/2025/10/27/2025102717070964360_l.jpg" name="twitter:image"/>
#        <meta content="https://www.ddaily.co.kr//page/view/2025102717081235863" name="twitter:url"/>
#        <!-- Google Tag Manager -->
#        <script>
#         (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='datalayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','datalayer','GTM-KNJCXCWG');
#        </script>
#        <!-- End Google Tag Manager -->
#        <link href="/assets/css/reset.css" rel="stylesheet" type="text/css"/>
#        <link href="/assets/css/jquery-ui.css" rel="stylesheet" type="text/css"/>
#        <link href="/assets/css/slick.css" rel="stylesheet" type="text/css"/>
#        <link href="/assets/css/slick-theme.css" rel="stylesheet" type="text/css"/>
#        <link href="/assets/css/skin.css" rel="stylesheet" type="text/css"/>
#        <link href="/assets/css/common.css?v=1.0.5" rel="stylesheet" type="text/css"/>
#        <link href="/assets/css/style.css?v=1.0.5" rel="stylesheet" type="text/css"/>
#        <link href="/assets/css/bulma.css?v=1.0.5" rel="stylesheet" type="text/css"/>
#        <link href="//maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet" type="text/css">
#         <style>
#          /* 캡챠 자동등록(입력)방지 기본 -pc 시작 */
# 			#captcha {display:inline-block;position:relative}
# 			#captcha legend {position:absolute;margin:0;padding:0;font-size:0;line-height:0;text-indent:-9999em;overflow:hidden}
# 			#captcha #captcha_img {height:80px;border:1px solid #898989;vertical-align:top;padding:0;margin:0}
# 			#captcha #captcha_mp3 {margin:0;padding:0;width:40px;height:40px;border:0;background:transparent;vertical-align:middle;overflow:hidden;cursor:pointer;background:url('/assets/nwcms/sample/site/images/common/captcha2.png') no-repeat;text-indent:-999px;border-radius:3px}
# 			#captcha #captcha_reload {margin:0;padding:0;width:40px;height:40px;border:0;background:transparent;vertical-align:middle;overflow:hidden;cursor:pointer;background:url('/assets/nwcms/sample/site/images/common/captcha2.png') no-repeat 0 -40px;text-indent:-999px;border-radius:3px}
# 			#captcha #captcha_key {margin:0 0 0 3px;padding:0 5px;width:90px;height:40px;border:1px solid #ccc;background:#fff;font-size:1.333em;font-weight:bold;text-align:center;border-radius:3px;vertical-align:top}
# 			#captcha #captcha_info {display:block;margin:5px 0 0;font-size:0.95em;letter-spacing:-0.1em}
# 			/* 캡챠 자동등록(입력)방지 기본 -pc 끝 */
#         </style>
#         <script src="/assets/js/jquery-1.12.4.js">
#         </script>
#         <script src="/assets/js/jquery-ui.js">
#         </script>
#         <script src="/assets/js/slick.js">
#         </script>
#         <script src="/assets/js/skin.js">
#         </script>
#         <script src="/assets/js/VerLim.min.js">
#         </script>
#         <script src="/assets/js/masonry.pkgd.min.js">
#         </script>
#         <script src="/assets/js/common.js?v=1.0.0">
#         </script>
#         <link href="http://m.ddaily.co.kr" media="only screen and (max-width: 640px)" rel="alternate">
#          <script src="//maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js" type="text/javascript">
#          </script>
#          <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-5843430185166617">
#          </script>
#          <!-- Google tag (gtag.js) -->
#          <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-2SLMBJ9Y8B">
#          </script>
#          <script>
#           window.dataLayer = window.dataLayer || [];
# 			function gtag(){dataLayer.push(arguments);}
# 			gtag('js', new Date());
#
# 			gtag('config', 'G-2SLMBJ9Y8B');
#          </script>
#         </link>
#        </link>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body>
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-KNJCXCWG" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <span itemscope="" itemtype="http://schema.org/Organization">
#    <link href="https://www.ddaily.co.kr/" itemprop="url"/>
#    <a href="https://media.naver.com/press/138" itemprop="sameAs">
#    </a>
#    <a href="https://www.facebook.com/official.digitaldaily" itemprop="sameAs">
#    </a>
#    <a href="https://twitter.com/officialddaily" itemprop="sameAs">
#    </a>
#    <a href="https://m.post.naver.com/ddaily0517" itemprop="sameAs">
#    </a>
#    <a href="https://www.instagram.com/official.digitaldaily/" itemprop="sameAs">
#    </a>
#    <a href="https://www.youtube.com/@official.digitaldaily" itemprop="sameAs">
#    </a>
#   </span>
#   <div id="wrap">
#    <style>
#     #wrap #header .header_top {background:#f8f8f8}
# #wrap #header .inner .issue_pick .list {height:48px;}
# #wrap #header .inner .header_content #gnb > ul > li .depth2_wrap {
# width:800px;
# }
# #wrap #header .inner .header_content #gnb > ul > li .depth2_wrap ul li {
# width:20%;
# }
#
# #wrap #header .inner .header_content #gnb {
#    margin:27px 0 0 195px;
# }
#
# #wrap #header .inner .header_content .search_box {
#     width: 222px;
# }
#
# #wrap #header .inner .header_content .search_box .search {
#    margin-top:18px;
# }
# #wrap #header .inner .header_content .header_right .search_box .total_menu_btn {
#   margin-top:25px;
# }
#
# #wrap #header .inner .header_content .search_box .search .search_btn {
#    padding:10px 0 0 2px;
# }
#
# #wrap #header .inner .header_content .today {
#   font-size: 14px;
#   color: #666;
#   text-align: right;
# }
#
# /*.wing_banner .wb_right .wcms_banner {position:fixed;}*/
#
# #wrap #header .inner .header_content {
#   display:flex;
# }
#
# #wrap #header .inner .header_content #gnb {
#  margin: 27px 0 0 auto;
# }
#
# #wrap #header .inner .header_content #logo img {
# max-width:410px;
# }
#    </style>
#    <script>
#     $(window).scroll(function() {
#         var scrolltop = $(this).scrollTop();
#         //console.log(scrolltop );
#         if(scrolltop < 100) {
#             $(".wb_left").stop().animate({top:scrolltop + 'px'}, 500, 'linear');
#             $(".wb_right").stop().animate({top:scrolltop + 'px'}, 500, 'linear');
#         } else {
#             $(".wb_left").stop().animate({top:scrolltop - 150 + 'px'}, 500, 'linear');
#             $(".wb_right").stop().animate({top:scrolltop - 150 + 'px'}, 500, 'linear');
#         }
#     });
#    </script>
#    <!-- 헤더 시작 -->
#    <div id="header">
#     <!-- 헤더 탑 시작 -->
#     <div class="header_top">
#      <div class="inner">
#       <!-- 상단 광고 시작 -->
#       <div class="h20">
#       </div>
#       <div class="banner_wrap">
#        <div class="wcms_banner" id="7">
#         <iframe frameborder="0" height="90" leftmargin="0" marginheight="0" marginwidth="0" referrerpolicy="no-referrer-when-downgrade" scrolling="no" src="https://ads.netinsight.co.kr/NetInsight/html/Digital_Daily/DigitalDaily/DigitalDaily@A_All_TopBanner_970_90" topmargin="0" width="970">
#         </iframe>
#        </div>
#       </div>
#       <div class="h10">
#       </div>
#       <!-- 상단 광고 끝 -->
#       <div class="header_left">
#        <ul>
#         <!--li><a href="https://techcntlab.com/home" target="_blank">DD테크콘텐츠랩</a></li-->
#         <li>
#          <a href="https://www.delighti.co.kr" target="_blank">
#           딜라이트닷넷
#          </a>
#         </li>
#         <li>
#          <a href="https://ddtube.co.kr" target="_blank">
#           DD튜브
#          </a>
#         </li>
#         <li>
#          <a href="/seminar">
#           세미나/콘퍼런스
#          </a>
#         </li>
#         <li>
#          <a href="/special2025_L100">
#           창간 기념 이벤트
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="header_right">
#        <div class="util">
#         <ul>
#          <li>
#           <a href="javascript:window.open('/newsletter_join', 'newsletter_join', 'top=200, left=200, width=700, height=750');">
#            DD뉴스레터 보기
#           </a>
#          </li>
#          <li class="member">
#           <a href="/login">
#            로그인
#           </a>
#          </li>
#          <li class="member">
#           <a href="/member/join">
#            회원가입
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#     </div>
#     <!-- 헤더 탑 끝 -->
#     <div class="inner">
#      <div class="txtr">
#       <p class="today">
#        2025.10.27
#       </p>
#      </div>
#      <div class="header_content">
#       <h1 id="logo">
#        <a href="/">
#         <img alt="디지털데일리" src="/assets/images/common/logo_20th_new.jpg" style="margin-bottom:10px;"/>
#        </a>
#       </h1>
#       <!-- gnb 시작 -->
#       <div id="gnb">
#        <ul>
#         <li>
#          <a href="/news" target="_self">
#           뉴스
#          </a>
#          <div class="depth2_wrap">
#           <div class="inner">
#            <div class="title">
#             <h2>
#              뉴스
#             </h2>
#            </div>
#            <div class="menu">
#             <ul>
#              <li>
#               <a href="/newest" target="_self">
#                최신뉴스
#               </a>
#              </li>
#              <li>
#               <a href="/media" target="_self">
#                통신/미디어
#               </a>
#              </li>
#              <li>
#               <a href="/semiconductor" target="_self">
#                반도체/소부장
#               </a>
#              </li>
#              <li>
#               <a href="/platform" target="_self">
#                플랫폼/유통
#               </a>
#              </li>
#              <li>
#               <a href="/device" target="_self">
#                IT기기
#               </a>
#              </li>
#              <li>
#               <a href="/enterprise" target="_self">
#                엔터프라이즈 솔루션
#               </a>
#              </li>
#              <li>
#               <a href="/game" target="_self">
#                게임/콘텐츠
#               </a>
#              </li>
#              <li>
#               <a href="/finance" target="_self">
#                금융
#               </a>
#              </li>
#              <li>
#               <a href="/mobility" target="_self">
#                모빌리티
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li>
#          <a href="/ai" target="_self">
#           AI
#          </a>
#         </li>
#         <li>
#          <a href="/industry" target="_self">
#           산업
#          </a>
#         </li>
#         <li>
#          <a href="/economy" target="_self">
#           경제
#          </a>
#         </li>
#         <li>
#          <a href="/life" target="_self">
#           생활/문화
#          </a>
#         </li>
#         <li>
#          <a href="/opinion" target="_self">
#           오피니언
#          </a>
#         </li>
#         <li>
#          <a href="/governance" target="_self">
#           거버넌스
#          </a>
#         </li>
#        </ul>
#        <div class="total_menu_btn">
#         <div class="bar1">
#         </div>
#         <div class="bar2">
#         </div>
#         <div class="bar3">
#         </div>
#        </div>
#       </div>
#       <!-- gnb 끝 -->
#       <div class="header_right">
#        <div class="search_box">
#         <div class="search">
#          <input id="header_search" name="qt" type="text" value=""/>
#          <span class="search_btn" id="header_search_btn">
#           <img alt="검색" src="/assets/images/common/icon_search.png"/>
#          </span>
#         </div>
#         <div class="total_menu_btn">
#          <div class="bar1">
#          </div>
#          <div class="bar2">
#          </div>
#          <div class="bar3">
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <!-- 햄버거 메뉴 시작 -->
#      <div class="total_menu_wrap">
#       <div class="column_wrap">
#        <div class="column">
#         <h3 class="title">
#          뉴스
#         </h3>
#         <ul>
#          <li>
#           <a href="/media">
#            통신/미디어
#           </a>
#          </li>
#          <li>
#           <a href="/semiconductor">
#            반도체/소부장
#           </a>
#          </li>
#          <li>
#           <a href="/game">
#            게임/콘텐츠
#           </a>
#          </li>
#          <li>
#           <a href="/enterprise">
#            엔터프라이즈 솔루션
#           </a>
#          </li>
#          <li>
#           <a href="/finance">
#            금융
#           </a>
#          </li>
#          <li>
#           <a href="/platform">
#            플랫폼/유통
#           </a>
#          </li>
#          <li>
#           <a href="/commerce">
#            커머스
#           </a>
#          </li>
#          <li>
#           <a href="/device">
#            IT기기
#           </a>
#          </li>
#          <li>
#           <a href="/mobility">
#            모빌리티
#           </a>
#          </li>
#          <li>
#           <a href="/news">
#            전체기사
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="column">
#         <h3 class="title">
#          기획/특집
#         </h3>
#         <ul>
#          <li>
#           <a href="/tech">
#            테크
#           </a>
#          </li>
#          <li>
#           <a href="/review">
#            리뷰
#           </a>
#          </li>
#          <li>
#           <a href="/fun">
#            FUN
#           </a>
#          </li>
#          <li>
#           <a href="/money">
#            머니&amp;코인
#           </a>
#          </li>
#          <li>
#           <a href="/opinion">
#            오피니언
#           </a>
#          </li>
#          <li>
#           <a href="/governance">
#            거버넌스
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="column additional">
#         <h3 class="title">
#          부가서비스
#         </h3>
#         <ul>
#          <li>
#           <a href="/seminar">
#            세미나/콘퍼런스
#           </a>
#          </li>
#          <li>
#           <a href="https://www.ddtube.co.kr/" target="_blank">
#            웨비나
#           </a>
#          </li>
#          <li>
#           <a href="/microsite">
#            마이크로사이트
#           </a>
#          </li>
#          <li>
#           <a href="/whitepaper">
#            자료실
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#      <!-- 햄버거 메뉴 끝 -->
#      <!-- 이슈픽 시작 -->
#      <div class="issue_pick">
#       <div class="title">
#        실시간뉴스
#       </div>
#       <div class="list">
#        <div class="controls">
#         <img alt="prev" class="btn_prev" src="/assets/images/common/icon_arw_prev.png"/>
#         <img alt="next" class="btn_next" src="/assets/images/common/icon_arw_next.png"/>
#        </div>
#        <ul>
#         <!--<li>
#                         <h3>
#                             <a href="{wcms_link}">{wcms_category}</a>
#                         </h3>
#                         <p>
#                             <a href="{wcms_link}">{wcms_title}</a>
#                         </p>
#                     </li>-->
#        </ul>
#       </div>
#      </div>
#      <!-- 이슈픽 끝 -->
#     </div>
#    </div>
#    <!-- 헤더 끝 -->
#    <div class="h20">
#    </div>
#    <script>
#     $(function(){
#         $.ajax({
#             url     : '/api.php',
#             type    : "POST",
#             dataType: "JSON",
#             data    : {"class" : "/api/getIssuePick"},
#             success : function(result) {
#                 var html    = '';
#                 $.each(result, function(i, data){
#                     html    += '<li>';
#                     html    += '    <h3>';
#                     html    += '        <a href="/page/view/'+data.code+'">'+data.category_name+'</a>';
#                     html    += '    </h3>';
#                     html    += '    <p>';
#                     html    += '        <a href="/page/view/'+data.code+'">'+data.title+'</a>';
#                     html    += '    </p>';
#                     html    += '</li>';
#                 });
#                 $(".issue_pick ul").append(html);
#                 $("#wrap #header .inner .issue_pick .list ul").slick({
#                     slidesToShow: 4,
#                     slidesToScroll: 1,
#                     autoplay: true,
#                     autoplaySpeed: 3000,
#                     arrows: true,
#                     infinite: true,
#                     swipte: true,
#                     prevArrow: $('.issue_pick .btn_prev'),
#                     nextArrow: $('.issue_pick .btn_next')
#                 });
#             }
#         });
#
#         $('#header_search').keypress(function(e){
#             if(e.which === 13){
#                 var text = encodeURIComponent($(this).val());
#                 newsSearch(text);
#             }
#         });
#
#         $('#header_search_btn').click(function(){
#             var text = encodeURIComponent($('#header_search').val());
#             newsSearch(text);
#         });
#     });
#
#     function newsSearch(text){
#         location.href = '/search?sort=1&search=' + text;
#     }
#    </script>
#    <div id="container">
#     <!--script src="https://developers.kakao.com/sdk/js/kakao.min.js"></script-->
#     <script src="https://t1.kakaocdn.net/kakao_js_sdk/2.4.0/kakao.min.js">
#     </script>
#     <script src="/assets/js/ami_analytics.js">
#     </script>
#     <style>
#      .art_mid_ad {text-align:center !important; margin-bottom:30px;}
#     .article_bottom_ad {width:100%; display:flex; justify-content:space-between;}
#     .wing_banner {
#         position: absolute;
#         width: 1180px;
#     }
#     .wing_banner .wb_left {
#         position: absolute;
#         left: -200px;
#         width: 160px;
#     }
#     .wing_banner .wb_right {
#         position: absolute;
#         right: -310px;
#         width: 160px;
#     }
#     </style>
#     <script>
#      $(function() {
#         var idx = $(".article_content").contents().length;
#         if (idx > 0) {
#             $(".article_content").contents().eq(9).after($("#art_mid_ad1"));
#             $("#art_mid_ad1").show();
#
#             $(".article_content").contents().eq(16).after($("#art_mid_ad2"));
#             $("#art_mid_ad2").show();
#         }
#
#         if (idx < 17) {
#             $("#art_mid_ad2").hide();
#         }
#
#         if (idx < 10) {
#             $("#art_mid_ad1").hide();
#         }
#
#         $.ajax({
#             url     : "/api.php",
#             type    : "POST",
#             dataType: "JSON",
#             data    : {"class" : "/api/getCategory", "code" : $("#ca_code").val()},
#             success : function(result) {
#                 if( result.status == "success" ){
#                     console.log("카테고리 = " + result.category);
#                     console.log("카테고리 결과 = " + result.category.indexOf("310"));
#                     if( result.category.indexOf("296") != -1 ){
#                         $("#42").show();
#                     }
#                     if( result.category.indexOf("297") != -1 ){
#                         $("#45").show();
#                     }
#                     if( result.category.indexOf("298") != -1 ){
#                         $("#43").show();
#                     }
#                     if( result.category.indexOf("299") != -1 ){
#                         $("#44").show();
#                     }
#                     if( result.category.indexOf("301") != -1 ){
#                         $("#46").show();
#                     }
#                     if( result.category.indexOf("302") != -1 ){
#                         $("#47").show();
#                     }
#                     if( result.category.indexOf("303") != -1 ){
#                         $("#48").show();
#                     }
#                     if( result.category.indexOf("304") != -1 ){
#                         $("#49").show();
#                     }
#                     if( result.category.indexOf("305") != -1 ){
#                         $("#50").show();
#                     }
#                     if( result.category.indexOf("306") != -1 ){
#                         $("#51").show();
#                     }
#                     if( result.category.indexOf("307") != -1 ){
#                         $("#52").show();
#                     }
#                     if( result.category.indexOf("308") != -1 ){
#                         $("#53").show();
#                     }
#                     if( result.category.indexOf("309") != -1 ){
#                         $("#54").show();
#                     }
#                     if( result.category.indexOf("310") != -1 ){
#                         $("#55").show();
#                     }
#                 }
#             }
#         });
#     });
#     </script>
#     <div class="art_mid_ad" id="art_mid_ad1" style="width:729px; margin:0 auto; display:none;">
#      <ins class="adsbygoogle" data-ad-client="ca-pub-5843430185166617" data-ad-slot="6758177907" style="display:inline-block;width:728px;height:90px">
#      </ins>
#      <script>
#       (adsbygoogle = window.adsbygoogle || []).push({});
#      </script>
#     </div>
#     <div class="art_mid_ad" id="art_mid_ad2" style="display:none;">
#      <ins class="adsbygoogle" data-ad-client="ca-pub-5843430185166617" data-ad-slot="6758177907" style="display:inline-block;width:728px;height:90px">
#      </ins>
#      <script>
#       (adsbygoogle = window.adsbygoogle || []).push({});
#      </script>
#     </div>
#     <div class="inner">
#      <!-- 기사 헤드 시작 -->
#      <div class="wing_banner">
#       <div class="wb_left">
#        <div class="wcms_banner" id="36">
#         <ins class="adsbygoogle" data-ad-client="ca-pub-5843430185166617" data-ad-slot="4440230545" style="display:inline-block;width:160px;height:600px">
#         </ins>
#         <script>
#          (adsbygoogle = window.adsbygoogle || []).push({});
#         </script>
#        </div>
#       </div>
#       <div class="wb_right">
#        <div class="wcms_banner" id="32">
#         <iframe frameborder="0" height="600" leftmargin="0" marginheight="0" marginwidth="0" referrerpolicy="no-referrer-when-downgrade" scrolling="no" src="https://ads.netinsight.co.kr/NetInsight/html/Digital_Daily/DigitalDaily/DigitalDaily@W_All_WingBanner1_160_600" topmargin="0" width="160">
#         </iframe>
#        </div>
#       </div>
#      </div>
#      <div class="article_head">
#       <div style="text-align: center; margin-bottom:10px;">
#        <div class="wcms_banner" id="42" style="display: none;">
#         <a href="/wcms_ad.php?ads_idx=73" target="_blank">
#          <img height="200" src="/upload/ads/2024/01/30/f37bd37c97f092f313c5d59d0cb6f1d2.jpg" width="1300"/>
#         </a>
#        </div>
#        <div class="wcms_banner" id="43" style="display: none;">
#         <a href="/wcms_ad.php?ads_idx=74" target="_blank">
#          <img height="200" src="/upload/ads/2024/01/30/73839b2a3524098228396c9b62c90267.jpg" width="1300"/>
#         </a>
#        </div>
#        <div class="wcms_banner" id="44" style="display: none;">
#         <a href="/wcms_ad.php?ads_idx=75" target="_blank">
#          <img height="200" src="/upload/ads/2024/01/30/d4339f3dbc618d5f51573a0246d91ab8.jpg" width="1300"/>
#         </a>
#        </div>
#        <div class="wcms_banner" id="45" style="display: none;">
#         <a href="/wcms_ad.php?ads_idx=76" target="_blank">
#          <img height="200" src="/upload/ads/2024/01/30/cb8ee9b3ea353c3326ca1007238e6b3b.jpg" width="1300"/>
#         </a>
#        </div>
#        <div class="wcms_banner" id="46" style="display: none;">
#         <a href="/wcms_ad.php?ads_idx=78" target="_blank">
#          <img height="200" src="/upload/ads/2024/02/02/ccf4fd622ed2a3ee7c4a3e847daf5667.jpg" width="1300"/>
#         </a>
#        </div>
#        <div class="wcms_banner" id="47" style="display: none;">
#         <a href="/wcms_ad.php?ads_idx=82" target="_blank">
#          <img height="200" src="/upload/ads/2024/03/18/b2972ef1073c864cb2847cd7c8a48b40.jpg" width="1300"/>
#         </a>
#        </div>
#        <div class="wcms_banner" id="48" style="display: none;">
#         <a href="/wcms_ad.php?ads_idx=87" target="_blank">
#          <img height="200" src="/upload/ads/2024/04/16/02b990c8a254256a5a11d2f962ee3c8d.jpg" width="1300"/>
#         </a>
#        </div>
#        <div class="wcms_banner" id="49" style="display: none;">
#         <a href="/wcms_ad.php?ads_idx=88" target="_blank">
#          <img height="200" src="/upload/ads/2024/04/23/e116d21c489c3c352624f082ed507552.jpg" width="1300"/>
#         </a>
#        </div>
#        <div class="wcms_banner" id="50" style="display: none;">
#         <a href="/wcms_ad.php?ads_idx=91" target="_blank">
#          <img height="200" src="/upload/ads/2024/05/14/9b58a746a46904230c0687e0b38c6db3.jpg" width="1300"/>
#         </a>
#        </div>
#        <div class="wcms_banner" id="51" style="display: none;">
#         <a href="/wcms_ad.php?ads_idx=95" target="_blank">
#          <img height="200" src="/upload/ads/2024/06/12/2e1b35e0664823ba3a48374946bebb6b.jpg" width="1300"/>
#         </a>
#        </div>
#        <div class="wcms_banner" id="52" style="display: none;">
#         <a href="/wcms_ad.php?ads_idx=99" target="_blank">
#          <img height="200" src="/upload/ads/2024/07/03/1e399a6270849338721feb22f3d2b72e.jpg" width="1300"/>
#         </a>
#        </div>
#        <div class="wcms_banner" id="53" style="display: none;">
#         <a href="/wcms_ad.php?ads_idx=108" target="_blank">
#          <img height="200" src="/upload/ads/2024/10/14/47d358dc0b9c88d2061573c34ca582ba.jpg" width="1300"/>
#         </a>
#        </div>
#        <div class="wcms_banner" id="54" style="display: none;">
#         <a href="/wcms_ad.php?ads_idx=110" target="_blank">
#          <img height="110" src="/upload/ads/2024/11/06/ad1d19b5df75fecce94af794dc01d93a.jpg" width="1300"/>
#         </a>
#        </div>
#        <div class="wcms_banner" id="55" style="display: none;">
#         <a href="/wcms_ad.php?ads_idx=114" target="_blank">
#          <img height="200" src="/upload/ads/2025/01/07/c6dfeadf288c0c0d9273cc6c30b0a53d.jpg" width="1300"/>
#         </a>
#        </div>
#       </div>
#       <span class="cate">
#        게임
#       </span>
#       <p class="title">
#        인기 인플루언서 총출동!…넷마블, '지스타2025' 현장 프로그램 공개
#       </p>
#       <div class="util_box">
#        <div class="byline">
#         <span class="company">
#          디지털데일리
#         </span>
#         <span class="date">
#          발행일 2025-10-27 17:19:10
#         </span>
#        </div>
#        <div class="tools">
#         <ul class="btns">
#          <li class="font_down" onclick="fontsize('down')">
#           가
#          </li>
#          <li class="font_up" onclick="fontsize('up')">
#           가
#          </li>
#          <li class="print">
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#      <!-- 기사 헤드 끝 -->
#      <!-- 섹션 시작 -->
#      <div class="section">
#       <div class="article_view">
#        <div class="info">
#         <span class="writer">
#          이학범 기자
#         </span>
#         <!--<span class="subscribe">구독중</span>
#                 <span class="newsstand">
#                     <img src="/assets/images/common/icon_newsstand.png" alt="네이버">
#                     구독
#                 </span>-->
#         <span class="split">
#         </span>
#         <ul>
#          <li>
#           <a href="javascript:;" id="kakao-link-btn">
#            <img alt="카카오 공유하기" src="/assets/images/common/icon_kko.png"/>
#           </a>
#          </li>
#          <li>
#           <a href="javascript:facebook_share();">
#            <img alt="페이스북 공유하기" src="/assets/images/common/icon_fb.png"/>
#           </a>
#          </li>
#          <li>
#           <a href="javascript:twitter_share();">
#            <img alt="트위치 공유하기" src="/assets/images/common/icon_tw.png"/>
#           </a>
#          </li>
#          <li>
#           <a href="javascript:naver_share();">
#            <img alt="네이버 공유하기" src="/assets/images/common/icon_nv.png"/>
#           </a>
#          </li>
#          <li>
#           <a href="mailto:ethic95@ddaily.co.kr">
#            <img alt="기사 공유하기" src="/assets/images/common/icon_mail.png"/>
#           </a>
#          </li>
#         </ul>
#        </div>
#        <!-- 기사 시작 -->
#        <div class="article_content">
#         <div class="view_img img_center">
#          <img src="/photos/2025/10/27/2025102717070964360_l.jpg">
#           <p class="caption">
#            넷마블 ‘지스타 2025' 출품작. [ⓒ넷마블]
#           </p>
#          </img>
#         </div>
#         <p>
#          [디지털데일리 이학범기자] 넷마블은 오는 11월13일부터 16일까지 부산 벡스코에서 열리는 '지스타2025'에서 진행되는 출품작 5종의 현장 프로그램을 공개했다고 27일 밝혔다.
#         </p>
#         <p>
#         </p>
#         <p>
#          올해 넷마블은 '프로젝트 이블베인', '나혼자만레벨업: 카르마', '일곱개의대죄: 오리진', '몬길: 스타다이브', '솔: 인챈트' 총 5종을 출품한다. 시연관은 총 112부스 규모로 145개 시연대로 구성됐다. 중앙에 위치한 무대에서는 다양한 현장 프로그램이 진행된다. 넷마블 부스 내에는 일곱개의대죄: 오리진의 주요 캐릭터 '다이앤'의 거대 조형물과 몬길: 스타다이브의 마스코트 캐릭터 '야옹이'가 전시된다.
#         </p>
#         <p>
#         </p>
#         <p>
#          넷마블은 공식 사이트를 통해 사전 등록 및 SNS 채널 리그램 이벤트 참여자들을 대상으로 추첨을 통해 지스타 초대권과 스토어 경품 등을 증정한다. 현장에서도 경품 퀴즈쇼 등 풍성한 이벤트와 경품을 제공할 예정이다.
#         </p>
#         <p>
#         </p>
#         <div class="view_img img_center">
#          <img src="/photos/2025/10/27/2025102717073951155_l.jpg">
#           <p class="caption">
#            넷마블 '지스타 2025' 부스 조감도. [ⓒ넷마블]
#           </p>
#          </img>
#         </div>
#         <p>
#          출품작별 프로그램도 다양하게 마련한다. 먼저 처음으로 시연이 진행되는 프로젝트 이블베인은 인기 인플루언서 김성회, 닛몰캐쉬 등의 협동 플레이 시연이 진행된다. 나혼자만레벨업: 카르마는 개발 총괄 PD가 무대에 올라 게임 소개 및 질의응답을 진행하며 닛몰캐쉬, 일오팔, 룩삼 등의 인플루언서와 함께하는 타임어택 대결이 펼쳐진다.
#         </p>
#         <p>
#         </p>
#         <p>
#          일곱개의대죄: 오리진은 서새봄, 옥냥이, 따효니 등 인기 인플루언서와 함께 보스 몬스터를 처치하는 타임어택 챌린지가 진행된다. 넷마블은 행사 기간 마지막 무대에서 인플루언서들이 직접 플레이스테이션5 프로 등을 선물하는 추첨 이벤트도 실시한다. 16일에는 버추얼 아티스트 헤비가 참여한 시연 이벤트가 열린다.
#         </p>
#         <p>
#         </p>
#         <p>
#          몬길: 스타다이브는 개발자 토크쇼가 진행된다. 인플루언서 김성회의 진행으로 개발진이 게임 개발 뒷이야기를 소개하는 등 방문객들과 소통할 예정이다. 이외에도 주요 캐릭터 성우들이 캐릭터를 소개하는 성우 토크쇼와 메인 캐릭터 코스튬 플레이쇼 등이 마련된다.
#         </p>
#         <p>
#         </p>
#         <p>
#          야외 부스에서는 미공개 신작인 솔: 인챈트의 체험 이벤트가 열린다. 인터랙션(상호작용) 미디어 아트가 구현된 부스에서 게임의 핵심 콘텐츠인 신권을 간접 체험할 수 이벤트가 운영된다. 관람객들은 신권 아이디어 공모 이벤트, 유튜브 채널 구독 이벤트 등에 참여해 이벤트 코인을 얻어 경품을 교환할 수 있다.
#         </p>
#         <p>
#         </p>
#         <p>
#          이외에도 넷마블은 11월17일 출시 예정인 '나혼자만레벨업:어라이즈 오버드라이브'의 시연 프로그램도 운영할 예정이다.
#         </p>
#        </div>
#        <div class="copyright">
#         Copyright ⓒ 디지털데일리. 무단전재 및 재배포 금지
#        </div>
#        <!-- 기사 끝 -->
#        <!-- 기자 전체기사 보기 시작 -->
#        <div class="writer_box">
#         <div class="name">
#          이학범 기자
#         </div>
#         <div class="mail">
#          ethic95@ddaily.co.kr
#         </div>
#         <a class="writer_article_more" href="javascript:authorList();">
#          기자의 전체기사 보기
#          <img alt="기자의 전체기사 보기" src="/assets/images/skin_img/arl_011_more.png"/>
#         </a>
#        </div>
#        <!-- 기자 전체기사 보기 끝 -->
#       </div>
#       <div class="h45">
#       </div>
#       <div>
#        <!-- 관련기사 시작 -->
#        <div class="rel_list">
#         <h2>
#          이 기사와 관련된 기사
#         </h2>
#         <ul>
#          <li>
#           <p class="title">
#            <a href="/page/view/2025101316513828635">
#             넷마블, '지스타 2025' 출품작 4종 공개…'나혼렙' IP 신작 나온다
#            </a>
#           </p>
#          </li>
#          <li>
#           <p class="title">
#            <a href="/page/view/2025101411255155065">
#             남미서도 통했다! 넷마블 '몬길: 스타다이브', 'BGS 2025'서 호평
#            </a>
#           </p>
#          </li>
#          <li>
#           <p class="title">
#            <a href="/page/view/2025101715001271596">
#             넷마블, 신작 '나혼렙:오버드라이브' 게임 플레이 영상 공개
#            </a>
#           </p>
#          </li>
#          <li>
#           <p class="title">
#            <a href="/page/view/2025102015325636798">
#             [현장] “게임보다 웹소설이 먼저?”…넷마블, 선런칭 전략으로 세계관 확장 견인
#            </a>
#           </p>
#          </li>
#          <li>
#           <p class="title">
#            <a href="/page/view/2025102116324611251">
#             넷마블, 신작 트로이카 흥행…'2025 대한민국 게임대상' 수상 전망은
#            </a>
#           </p>
#          </li>
#         </ul>
#        </div>
#        <!-- 관련기사 끝 -->
#       </div>
#       <div class="h30">
#       </div>
#       <!-- 기자 정보 시작 -->
#       <!--<div class="journalist_box">
#             <div class="top">
#                 <div class="pic">
#                     <a href="#"><img src="/assets/images/common/journalist_pic.jpg" alt="사진"></a>
#                 </div>
#                 <div class="info">
#                     <span class="writer">이학범 기자</span>
#                     <span class="email">ethic95@ddaily.co.kr</span>
#                     <a href="#"><span class="subscribe">구독하기</span></a>
#                     <div class="part">
#                         디지털데일리 뉴스팀
#                     </div>
#                 </div>
#             </div>
#             <div class="journalist_rel_list">
#                 <ul>
#                     <li>
#                         <p class="title">
#                             <a href="#">최기영 전 장관과 닮은꼴?…이종호 과기정통부 후보자, “어제 통화”</a>
#                         </p>
#                     </li>
#                     <li>
#                         <p class="title">
#                             <a href="#">이종호 과기정통부 후보자, “과학-ICT 연결돼 있어…함께 혁신”</a>
#                         </p>
#                     </li>
#                     <li>
#                         <p class="title">
#                             <a href="#">이종호 과기정통부 장관 후보자 “미래 사회변화 선도·대응”</a>
#                         </p>
#                     </li>
#                 </ul>
#             </div>
#         </div>-->
#       <!-- 기자 정보 끝 -->
#       <div class="h30">
#       </div>
#       <div class="wcms_banner" id="14">
#        <iframe frameborder="0" height="90" leftmargin="0" marginheight="0" marginwidth="0" referrerpolicy="no-referrer-when-downgrade" scrolling="no" src="https://ads.netinsight.co.kr/NetInsight/html/Digital_Daily/DigitalDaily/DigitalDaily@H_Article_UnderBanner1_970_90" topmargin="0" width="970">
#        </iframe>
#       </div>
#       <!--div class="wcms_banner" id="56"></div-->
#       <div class="h20">
#       </div>
#       <a href="http://media.naver.com/channel/promotion.nhn?oid=138" target="_blank">
#        <img alt="디지털데일리가 직접 편집한 뉴스 채널" src="/assets/images/common/naver_channel.jpg" style="width:100%;"/>
#       </a>
#       <div class="h30">
#       </div>
#       <!-- 당신이 좋아할 만한 뉴스 시작 -->
#       <div class="favorite_news">
#        <h2>
#         당신이 좋아할 만한 뉴스
#        </h2>
#        <ul class="wcms_outline" control_type="A" dataset_filename="2023/02/03/11_12_1_view_like_news.json" id="view_like_news" list_cnt="6" paging_yn="N" step="1">
#         <li>
#          <div class="thumb">
#           <a href="/page/view/2025102717375321169">
#            <img alt="썸네일" src="https://www.ddaily.co.kr/photos/2025/10/27/2025102717372431364_m.jpg"/>
#           </a>
#          </div>
#          <p class="title">
#           <a href="/page/view/2025102717375321169">
#            "크리에이터·팬 3000명 한 자리에"…제2회 틱톡 어워즈 성료
#           </a>
#          </p>
#         </li>
#         <li>
#          <div class="thumb">
#           <a href="/page/view/2025102716393595624">
#            <img alt="썸네일" src="https://www.ddaily.co.kr/photos/2025/10/27/2025102712542437424_m.jpg"/>
#           </a>
#          </div>
#          <p class="title">
#           <a href="/page/view/2025102716393595624">
#            [DD퇴근길] "경주로 오라"…APEC서 만날 포용적 AI
#           </a>
#          </p>
#         </li>
#         <li>
#          <div class="thumb">
#           <a href="/page/view/2025102716265980756">
#            <img alt="썸네일" src="https://www.ddaily.co.kr/photos/2025/10/27/2025102716261271578_m.jpg"/>
#           </a>
#          </div>
#          <p class="title">
#           <a href="/page/view/2025102716265980756">
#            카톡 롤백 버전 막혔다…비공식 개발자 "디도스 때문"
#           </a>
#          </p>
#         </li>
#         <li>
#          <div class="thumb">
#           <a href="/page/view/2025102716193804386">
#            <img alt="썸네일" src="https://www.ddaily.co.kr/photos/2025/09/18/2025091809454879548_m.jpg"/>
#           </a>
#          </div>
#          <p class="title">
#           <a href="/page/view/2025102716193804386">
#            미래 먹거리 준비 착착…LG전자, '글로벌 사우스' 필두로 HVAC 총력
#           </a>
#          </p>
#         </li>
#         <li>
#          <div class="thumb">
#           <a href="/page/view/2025102716215077803">
#            <img alt="썸네일" src="https://www.ddaily.co.kr/photos/2025/10/27/2025102716210366201_m.jpg"/>
#           </a>
#          </div>
#          <p class="title">
#           <a href="/page/view/2025102716215077803">
#            퓌(fwee), ‘트와이스 나연’ 앰버서더 선정…“아시아 MZ 사로잡을 것”
#           </a>
#          </p>
#         </li>
#         <li>
#          <div class="thumb">
#           <a href="/page/view/2025102714472526893">
#            <img alt="썸네일" src="https://www.ddaily.co.kr/photos/2025/10/27/2025102714461063783_m.jpg"/>
#           </a>
#          </div>
#          <p class="title">
#           <a href="/page/view/2025102714472526893">
#            글로벌 VC가 주목한 아이겐클라우드, 차세대 블록체인 클라우드로 부상
#           </a>
#          </p>
#         </li>
#        </ul>
#       </div>
#       <!-- 당신이 좋아할 만한 뉴스 끝 -->
#       <div class="h20">
#       </div>
#       <div class="wcms_banner" id="15">
#        <iframe frameborder="0" height="90" leftmargin="0" marginheight="0" marginwidth="0" referrerpolicy="no-referrer-when-downgrade" scrolling="no" src="https://ads.netinsight.co.kr/NetInsight/html/Digital_Daily/DigitalDaily/DigitalDaily@I_Article_UnderBanner1_970_90" topmargin="0" width="970">
#        </iframe>
#       </div>
#       <div class="h50">
#       </div>
#       <!--  하단 광고 3개 -->
#       <div class="article_bottom_ad">
#        <div>
#         <!-- 웹_Q_기사 하단 배너3_300x250 -->
#         <ins class="adsbygoogle" data-ad-client="ca-pub-5843430185166617" data-ad-slot="5721262557" style="display:inline-block;width:300px;height:250px">
#         </ins>
#         <script>
#          (adsbygoogle = window.adsbygoogle || []).push({});
#         </script>
#        </div>
#        <div>
#         <!-- 웹_Q_기사 하단 배너3_300x250 -->
#         <ins class="adsbygoogle" data-ad-client="ca-pub-5843430185166617" data-ad-slot="5721262557" style="display:inline-block;width:300px;height:250px">
#         </ins>
#         <script>
#          (adsbygoogle = window.adsbygoogle || []).push({});
#         </script>
#        </div>
#        <div>
#         <!-- 웹_Q_기사 하단 배너3_300x250 -->
#         <ins class="adsbygoogle" data-ad-client="ca-pub-5843430185166617" data-ad-slot="5721262557" style="display:inline-block;width:300px;height:250px">
#         </ins>
#         <script>
#          (adsbygoogle = window.adsbygoogle || []).push({});
#         </script>
#        </div>
#       </div>
#       <div class="h50">
#       </div>
#      </div>
#      <!-- 섹션 끝 -->
#      <!-- 사이드 시작 -->
#      <div class="aside">
#       <div class="wcms_side">
#        <div class="txtc">
#         <div class="wcms_banner" id="28">
#          <a href="/wcms_ad.php?ads_idx=136" target="_blank">
#           <img height="100" src="/upload/ads/2025/10/27/cbfd25a0cd8b804b969b5ec4e7140c4d.png" width="300"/>
#          </a>
#         </div>
#        </div>
#        <div class="h20">
#        </div>
#        <div class="txtc">
#         <div class="wcms_banner" id="29">
#          <a href="/wcms_ad.php?ads_idx=120" target="_blank">
#           <img height="100" src="/upload/ads/2025/05/14/c0af5cd19c56e6e0a528461797ad33b9.jpg" width="300"/>
#          </a>
#         </div>
#        </div>
#        <div class="h20">
#        </div>
#        <div class="wcms_banner banner_b" id="8">
#         <iframe frameborder="0" height="300" leftmargin="0" marginheight="0" marginwidth="0" referrerpolicy="no-referrer-when-downgrade" scrolling="no" src="https://ads.netinsight.co.kr/NetInsight/html/Digital_Daily/DigitalDaily/DigitalDaily@B_All_RightBanner1_300_300" topmargin="0" width="300">
#         </iframe>
#        </div>
#        <div class="h20">
#        </div>
#        <!-- 기사리스트 001 시작 -->
#        <div class="arl_001">
#         <h2>
#          많이 본 기사
#         </h2>
#         <ul class="wcms_bestnews">
#          <li>
#           <p class="title">
#            <a href="/page/view/2025102714073235065">
#             삼성전자, 평택 P4에 HBM4 전력투입…'AI 메모리 중심 설비' 재편 가속 [소부장반차장]
#            </a>
#           </p>
#          </li>
#          <li>
#           <p class="title">
#            <a href="/page/view/2025102622251024681">
#             AI 브라우저 전쟁 개막…누가 인터넷 ‘첫 화면’을 차지할까?
#            </a>
#           </p>
#          </li>
#          <li>
#           <p class="title">
#            <a href="/page/view/2025102710153543042">
#             “도와달라”는 MBK, “말이 되냐”는 국회…홈플러스 회생 논쟁
#            </a>
#           </p>
#          </li>
#          <li>
#           <p class="title">
#            <a href="/page/view/2025102619074017502">
#             20조 투자부터 AI 컴퓨팅센터·안전 생태계까지... 'AI G3' 기틀 다지기 본격화
#            </a>
#           </p>
#          </li>
#          <li>
#           <p class="title">
#            <a href="/page/view/2025102710595052440">
#             해커가 데이터 빼 간 SK쉴더스, SKT·금융사 등 민관 120곳 정보 유출
#            </a>
#           </p>
#          </li>
#         </ul>
#        </div>
#        <!-- 기사리스트 001 끝 -->
#        <div class="h20">
#        </div>
#        <div class="wcms_banner banner_b" id="16">
#         <!-- 웹_J_기사 하단 배너3_300x100 -->
#         <ins class="adsbygoogle" data-ad-client="ca-pub-5843430185166617" data-ad-slot="8138550713" style="display:inline-block;width:300px;height:100px">
#         </ins>
#         <script>
#          (adsbygoogle = window.adsbygoogle || []).push({});
#         </script>
#        </div>
#        <div class="h20">
#        </div>
#        <!-- 기사리스트 011 시작 -->
#        <div class="arl_011">
#         <h2>
#          연재기사
#         </h2>
#         <ul class="wcms_outline" control_type="A" dataset_filename="2023/05/03/4_72_1_main_news_list_1.json" id="main_news_list_1" list_cnt="4" paging_yn="N" step="1">
#          <li>
#           <div class="thumb">
#            <a href="/page/view/2025102717375321169">
#             <img alt="썸네일" src="https://www.ddaily.co.kr/photos/2025/10/27/2025102717372431364_m.jpg"/>
#            </a>
#           </div>
#           <p class="cate">
#            플랫폼
#            <span class="more">
#             <a href="/page/view/2025102717375321169">
#              <img alt="더보기" src="/assets/images/skin_img/arl_011_more.png"/>
#             </a>
#            </span>
#           </p>
#           <p class="title">
#            <a href="/page/view/2025102717375321169">
#             "크리에이터·팬 3000명 한 자리에"…제2회 틱톡 어워즈 성료
#            </a>
#           </p>
#          </li>
#          <li>
#           <div class="thumb">
#            <a href="/page/view/2025102716393595624">
#             <img alt="썸네일" src="https://www.ddaily.co.kr/photos/2025/10/27/2025102712542437424_m.jpg"/>
#            </a>
#           </div>
#           <p class="cate">
#            AI
#            <span class="more">
#             <a href="/page/view/2025102716393595624">
#              <img alt="더보기" src="/assets/images/skin_img/arl_011_more.png"/>
#             </a>
#            </span>
#           </p>
#           <p class="title">
#            <a href="/page/view/2025102716393595624">
#             [DD퇴근길] "경주로 오라"…APEC서 만날 포용적 AI
#            </a>
#           </p>
#          </li>
#          <li>
#           <div class="thumb">
#            <a href="/page/view/2025102716265980756">
#             <img alt="썸네일" src="https://www.ddaily.co.kr/photos/2025/10/27/2025102716261271578_m.jpg"/>
#            </a>
#           </div>
#           <p class="cate">
#            플랫폼
#            <span class="more">
#             <a href="/page/view/2025102716265980756">
#              <img alt="더보기" src="/assets/images/skin_img/arl_011_more.png"/>
#             </a>
#            </span>
#           </p>
#           <p class="title">
#            <a href="/page/view/2025102716265980756">
#             카톡 롤백 버전 막혔다…비공식 개발자 "디도스 때문"
#            </a>
#           </p>
#          </li>
#          <li>
#           <div class="thumb">
#            <a href="/page/view/2025102716193804386">
#             <img alt="썸네일" src="https://www.ddaily.co.kr/photos/2025/09/18/2025091809454879548_m.jpg"/>
#            </a>
#           </div>
#           <p class="cate">
#            산업
#            <span class="more">
#             <a href="/page/view/2025102716193804386">
#              <img alt="더보기" src="/assets/images/skin_img/arl_011_more.png"/>
#             </a>
#            </span>
#           </p>
#           <p class="title">
#            <a href="/page/view/2025102716193804386">
#             미래 먹거리 준비 착착…LG전자, '글로벌 사우스' 필두로 HVAC 총력
#            </a>
#           </p>
#          </li>
#         </ul>
#        </div>
#        <!-- 기사리스트 011 끝 -->
#        <div class="h20">
#        </div>
#        <div class="wcms_banner banner_b" id="11">
#         <iframe frameborder="0" height="200" leftmargin="0" marginheight="0" marginwidth="0" referrerpolicy="no-referrer-when-downgrade" scrolling="no" src="https://ads.netinsight.co.kr/NetInsight/html/Digital_Daily/DigitalDaily/DigitalDaily@E_All_RightBanner2_300_200" topmargin="0" width="300">
#         </iframe>
#        </div>
#        <div class="h20">
#        </div>
#        <!-- 기사리스트 014 시작 -->
#        <div class="arl_014">
#         <h2>
#          <span>
#           실시간
#          </span>
#          추천 뉴스
#         </h2>
#         <ul class="wcms_outline" control_type="A" dataset_filename="2023/02/03/4_12_1_side_recom_news_list.json" id="side_recom_news_list" list_cnt="5" paging_yn="N" step="1">
#          <li>
#           <div class="thumb">
#            <a href="/page/view/2025102717375321169">
#             <img alt="썸네일" src="https://www.ddaily.co.kr/photos/2025/10/27/2025102717372431364_m.jpg"/>
#            </a>
#           </div>
#           <p class="title">
#            <a href="/page/view/2025102717375321169">
#             "크리에이터·팬 3000명 한 자리에"…제2회 틱톡 어워즈 성료
#            </a>
#           </p>
#           <span class="date">
#            2025-10-27 17:39:17
#           </span>
#          </li>
#          <li>
#           <div class="thumb">
#            <a href="/page/view/2025102716393595624">
#             <img alt="썸네일" src="https://www.ddaily.co.kr/photos/2025/10/27/2025102712542437424_m.jpg"/>
#            </a>
#           </div>
#           <p class="title">
#            <a href="/page/view/2025102716393595624">
#             [DD퇴근길] "경주로 오라"…APEC서 만날 포용적 AI
#            </a>
#           </p>
#           <span class="date">
#            2025-10-27 17:02:48
#           </span>
#          </li>
#          <li>
#           <div class="thumb">
#            <a href="/page/view/2025102716265980756">
#             <img alt="썸네일" src="https://www.ddaily.co.kr/photos/2025/10/27/2025102716261271578_m.jpg"/>
#            </a>
#           </div>
#           <p class="title">
#            <a href="/page/view/2025102716265980756">
#             카톡 롤백 버전 막혔다…비공식 개발자 "디도스 때문"
#            </a>
#           </p>
#           <span class="date">
#            2025-10-27 16:35:42
#           </span>
#          </li>
#          <li>
#           <div class="thumb">
#            <a href="/page/view/2025102716193804386">
#             <img alt="썸네일" src="https://www.ddaily.co.kr/photos/2025/09/18/2025091809454879548_m.jpg"/>
#            </a>
#           </div>
#           <p class="title">
#            <a href="/page/view/2025102716193804386">
#             미래 먹거리 준비 착착…LG전자, '글로벌 사우스' 필두로 HVAC 총력
#            </a>
#           </p>
#           <span class="date">
#            2025-10-27 16:26:54
#           </span>
#          </li>
#          <li>
#           <div class="thumb">
#            <a href="/page/view/2025102716215077803">
#             <img alt="썸네일" src="https://www.ddaily.co.kr/photos/2025/10/27/2025102716210366201_m.jpg"/>
#            </a>
#           </div>
#           <p class="title">
#            <a href="/page/view/2025102716215077803">
#             퓌(fwee), ‘트와이스 나연’ 앰버서더 선정…“아시아 MZ 사로잡을 것”
#            </a>
#           </p>
#           <span class="date">
#            2025-10-27 16:24:07
#           </span>
#          </li>
#         </ul>
#        </div>
#        <!-- 기사리스트 014 끝 -->
#        <div class="h20">
#        </div>
#        <div class="wcms_banner banner_b" id="17">
#         <!-- 웹_K_기사 우측 배너2_300x300 -->
#         <ins class="adsbygoogle" data-ad-client="ca-pub-5843430185166617" data-ad-slot="6715175832" style="display:inline-block;width:300px;height:300px">
#         </ins>
#         <script>
#          (adsbygoogle = window.adsbygoogle || []).push({});
#         </script>
#        </div>
#        <style>
#         #wrap #container .inner .right_area.w_300 {
#     width: 300px;
# }
# /* 기사리스트 001 시작 */
# .arl_001 h2 {
#   font-size: 18px;
#   font-weight: 600;
#   color: #111;
#   margin-bottom: 17px;
# }
#
# .arl_001 ul {
#   counter-reset: arl_001;
# }
#
# .arl_001 ul li {
#   counter-increment: arl_001;
#   margin-bottom: 12px;
# }
#
# .arl_001 ul li:after {
#   content: '';
#   clear: both;
#   display: block;
# }
#
# .arl_001 ul li:nth-child(n + 4):before {
#   color: #111;
# }
#
# .arl_001 ul li:last-child {
#   margin-bottom: 0;
# }
#
# .arl_001 ul li:before {
#   float: left;
#   width: 30px;
#   text-align: left;
#   content: counter(arl_001);
#   font-size: 28px;
#   font-weight: 600;
#   padding-top: 2px;
#   color: #f89931;
# }
#
# .arl_001 ul li .title {
#   float: right;
#   width: calc(100% - 30px);
#   font-size: 16px;
#   line-height: 24px;
#   max-height: 48px;
#   overflow: hidden;
# }
#
# .arl_001 ul li .title a {
#   color: #333;
# }
#
# /* 기사리스트 001 끝 */
#
# /* 기사리스트 011 시작 */
# .arl_011 {
#   border: 1px solid #ededed;
#   padding: 20px;
# }
#
# .arl_011 h2 {
#   font-size: 18px;
#   color: #111;
#   font-weight: 600;
#   margin-bottom: 20px;
# }
#
# .arl_011 h2 span {
#   color: #3a87c7;
# }
#
# .arl_011 ul li {
#   padding-bottom: 15px;
#   border-bottom: 1px solid #ededed;
#   margin-bottom: 15px;
# }
#
# .arl_011 ul li:after {
#   content: '';
#   clear: both;
#   display: block;
# }
#
# .arl_011 ul li:last-child {
#   padding-bottom: 0;
#   border-bottom: 0;
#   margin-bottom: 0;
# }
#
# .arl_011 ul li .thumb {
#   float: left;
#   width: 70px;
#   height: 51px;
#   overflow: hidden;
#   margin-right: 15px;
# }
#
# .arl_011 ul li .thumb img {
#   display: block;
#   width: 100%;
#   height: 100%;
# }
#
# .arl_011 ul li .cate {
#   position: relative;
#   color: #0070bd;
#   font-size: 14px;
#   font-weight: 600;
#   margin-bottom: 9px;
# }
#
# .arl_011 ul li .cate .more {
#   position: absolute;
#   top: 0;
#   right: 0;
# }
#
# .arl_011 ul li .title {
#   -webkit-transform: translateY(1px);
#           transform: translateY(1px);
#   font-size: 16px;
#   line-height: 24px;
#   max-height: 48px;
#   overflow: hidden;
# }
#
# .arl_011 ul li .title a {
#   color: #111;
# }
#
# /* 기사리스트 011 끝 */
#
# /* 기사리스트 014 시작 */
# .arl_014 {
#   border: 1px solid #ededed;
#   padding: 20px;
# }
#
# .arl_014 h2 {
#   font-size: 18px;
#   color: #111;
#   font-weight: 600;
#   margin-bottom: 20px;
# }
#
# .arl_014 h2 span {
#   color: #3a87c7;
# }
#
# .arl_014 ul li {
#   padding-bottom: 15px;
#   border-bottom: 1px solid #ededed;
#   margin-bottom: 15px;
# }
#
# .arl_014 ul li:after {
#   content: '';
#   clear: both;
#   display: block;
# }
#
# .arl_014 ul li:last-child {
#   padding-bottom: 0;
#   border-bottom: 0;
#   margin-bottom: 0;
# }
#
# .arl_014 ul li .thumb {
#   float: left;
#   width: 70px;
#   height: 70px;
#   overflow: hidden;
#   margin-right: 15px;
# }
#
# .arl_014 ul li .thumb img {
#   display: block;
#   width: 100%;
#   height: 100%;
# }
#
# .arl_014 ul li .title {
#   -webkit-transform: translateY(1px);
#           transform: translateY(1px);
#   font-size: 16px;
#   line-height: 24px;
#   max-height: 48px;
#   margin-bottom: 5px;
#   overflow: hidden;
# }
#
# .arl_014 ul li .title a {
#   color: #111;
# }
#
# .arl_014 ul li .date {
#   font-size: 14px;
#   color: #999;
# }
#
# /* 기사리스트 014 끝 */
#        </style>
#       </div>
#      </div>
#      <!-- 사이드 끝 -->
#      <div class="h20">
#      </div>
#      <div class="txtc">
#       <div class="wcms_banner" id="13">
#        <iframe frameborder="0" height="90" leftmargin="0" marginheight="0" marginwidth="0" referrerpolicy="no-referrer-when-downgrade" scrolling="no" src="https://ads.netinsight.co.kr/NetInsight/html/Digital_Daily/DigitalDaily/DigitalDaily@G_All_UnderBanner_970_90" topmargin="0" width="970">
#        </iframe>
#       </div>
#      </div>
#      <div class="h20">
#      </div>
#     </div>
#     <script>
#      Kakao.init('9531c7b92bfc67ed4f6f9025f377e356');
#     Kakao.Share.createDefaultButton({
#         container: '#kakao-link-btn',
#         objectType: 'feed',
#         content: {
#             title: '인기 인플루언서 총출동!&hellip;넷마블, `지스타2025` 현장 프로그램 공개',
#             description: '',
#             imageUrl: '/photos/2025/10/27/2025102717073951155_l.jpg',
#             link: {
#                 mobileWebUrl: 'https://ddaily.co.kr/m/page/view/2025102717081235863',
#                 webUrl: 'https://ddaily.co.kr/page/view/2025102717081235863'
#             }
#         }
#     });
#     function authorList(){
#         var form    = document.createElement('form');
#         var object  = document.createElement('input');
#         object.setAttribute('type', 'hidden');
#         object.setAttribute('name', 'code');
#         object.setAttribute('value', $("#ca_code").val());
#         form.appendChild(object);
#         form.setAttribute('method', 'post');
#         form.setAttribute('action', "/author");
#         document.body.appendChild(form);
#         form.submit();
#     }
#     </script>
#     <style>
#      /**/
# .article_view .info .writer {margin-right:0;}
# .article_head .title {word-break: keep-all;}
#     </style>
#    </div>
#    <script>
#    </script>
#    <style>
#     .footer_sns {display:flex; padding-top:20px;}
# .footer_sns a img {margin-right:10px; width:50px;}
# #wrap #footer .footer_content .info .banner img {
#     transform: translateY(60px);
# }
#    </style>
#    <!-- 푸터 시작 -->
#    <div id="footer">
#     <div class="inner">
#      <div class="footer_content">
#       <h1 class="logo">
#        <a href="/">
#         <img alt="디지털데일리" src="/assets/images/common/logo.png"/>
#        </a>
#       </h1>
#       <ul class="footer_link">
#        <li>
#         <a href="/company">
#          회사소개
#         </a>
#        </li>
#        <li>
#         <a href="/company_ad">
#          광고문의
#         </a>
#        </li>
#        <!--li>
#                     <a href="/guide">채용안내</a>
#                 </li-->
#        <li>
#         <a href="/privacy">
#          개인정보취급방침
#         </a>
#        </li>
#        <!--li>
#                     <a href="/member">회원약관</a>
#                 </li-->
#        <!--li>
#                     <a href="/refusal">이메일 무단수집거부</a>
#                 </li-->
#        <li>
#         <a href="/protection_policy">
#          청소년보호정책
#         </a>
#        </li>
#        <li>
#         <a href="/ethics">
#          윤리강령
#         </a>
#        </li>
#       </ul>
#       <div class="info">
#        <p>
#         회사명: ㈜디지털데일리｜제호: 디지털데일리｜등록번호 : 서울아00039｜등록발행연월일: 2005년 9월 6일｜사업자 등록번호: 101-86-13419
#         <br/>
#         주소: (04057)서울특별시 마포구 신촌로14길 24(노고산동 54-46)｜대표전화: 02-334-7781｜Fax: 02-334-7782
#         <br/>
#         발행인: 곽태헌｜편집인: 채수웅｜개인정보·청소년보호책임자: 오주엽
#        </p>
#        <div class="banner">
#         <img alt="한국인터넷신문협회" src="/assets/images/common/f_banner1.jpg"/>
#         <img alt="인터넷신문위원회 윤리강령을 준수합니다" src="/assets/images/common/f_banner2.jpg"/>
#        </div>
#       </div>
#       <!-- sns로고 시작 -->
#       <div class="footer_sns">
#        <a href="https://www.facebook.com/official.digitaldaily" target="_blank">
#         <img src="/upload/icon_f_fb.png"/>
#        </a>
#        <a href="https://twitter.com/officialddaily" target="_blank">
#         <img src="/upload/icon_f_tw.png"/>
#        </a>
#        <a href="https://m.post.naver.com/ddaily0517" target="_blank">
#         <img src="/upload/icon_f_nv.png"/>
#        </a>
#        <a href="https://www.instagram.com/official.digitaldaily/" target="_blank">
#         <img src="/upload/icon_f_ist.png"/>
#        </a>
#        <a href="https://www.youtube.com/@official.digitaldaily" target="_blank">
#         <img src="/upload/icon_f_yt.png"/>
#        </a>
#       </div>
#       <!-- sns로고 끝 -->
#      </div>
#     </div>
#     <div class="copyright_wrap">
#      <div class="inner">
#       <p class="copyright">
#        Copyright © DIGITAL DAILY Co.,Ltd. All Rights Reserved.
#       </p>
#      </div>
#     </div>
#    </div>
#    <!-- 푸터 끝 -->
#    <input id="ca_code" type="hidden" value="2025102717081235863">
#    </input>
#   </div>
#   <div aria-hidden="true" aria-labelledby="commentDeleteModalLabel" class="bu-modal fade" id="commentDeleteModal" role="dialog" tabindex="-1">
#    <div class="bu-modal-background">
#    </div>
#    <div class="bu-modal-card" role="document">
#     <div class="bu-modal-content">
#      <div class="bu-modal-card-head">
#       <h5 class="bu-modal-card-title" id="commentDeleteModalLabel">
#        댓글 삭제
#       </h5>
#       <button aria-label="Close" class="bu-delete" data-dismiss="modal" type="button">
#       </button>
#      </div>
#      <div class="bu-modal-card-body">
#       <input id="chk_cmt_password" type="password"/>
#      </div>
#      <div class="bu-modal-card-foot">
#       <button class="btn btn-secondary" data-dismiss="modal" type="button">
#        Close
#       </button>
#       <button class="btn btn-primary" data-cmt_id="" id="delete_comment_btn" type="button">
#        댓글삭제
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>

# %%
from html.parser import HTMLParser

class
